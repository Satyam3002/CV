# %%
# !git clone --depth 1 https://github.com/spMohanty/PlantVillage-Dataset.git
# Out:
# Cloning into 'PlantVillage-Dataset'...
# remote: Enumerating objects: 163214, done.
# remote: Counting objects: 100% (163214/163214), done.
# remote: Compressing objects: 100% (163119/163119), done.
# remote: Total 163214 (delta 93), reused 163211 (delta 93), pack-reused 0 (from 0)
# Receiving objects: 100% (163214/163214), 2.00 GiB | 19.99 MiB/s, done.
# Resolving deltas: 100% (93/93), done.
# Updating files: 100% (182401/182401), done.

# %%
import os

dataset_path = "PlantVillage-Dataset/raw/color"
classes = os.listdir(dataset_path)
print(f"Total classes: {len(classes)}")
print(classes)
# Out:
# Total classes: 38
# ['Cherry_(including_sour)___healthy', 'Tomato___Tomato_mosaic_virus', 'Pepper,_bell___healthy', 'Tomato___healthy', 'Soybean___healthy', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Squash___Powdery_mildew', 'Apple___Black_rot', 'Apple___healthy', 'Tomato___Late_blight', 'Raspberry___healthy', 'Potato___Late_blight', 'Potato___Early_blight', 'Tomato___Target_Spot', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Corn_(maize)___Northern_Leaf_Blight', 'Tomato___Bacterial_spot', 'Tomato___Septoria_leaf_spot', 'Grape___Esca_(Black_Measles)', 'Peach___Bacterial_spot', 'Grape___Black_rot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Tomato___Leaf_Mold', 'Orange___Haunglongbing_(Citrus_greening)', 'Apple___Cedar_apple_rust', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Apple___Apple_scab', 'Tomato___Early_blight', 'Corn_(maize)___healthy', 'Blueberry___healthy', 'Corn_(maize)___Common_rust_', 'Potato___healthy']

# %%
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
import torch

# Load augmented dataset with proper transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Ensure uniform image size
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataset = ImageFolder(dataset_path, transform=transform)

# Split into Train, Validation, and Test sets
train_size = int(0.6 * len(dataset))
val_size = int(0.2 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, val_size, test_size])

# Define DataLoaders
batch_size = 32

# When using U-Net for classification, the input shape is unchanged
# But we want to make sure the DataLoader's output fits with the U-Net architecture
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm
from torch.utils.data import DataLoader
import numpy as np
from torchvision import models
from torch.amp import GradScaler

# Define the UNet model for classification
import torch
import torch.nn as nn
import torchvision.models as models

class UNetClassification(nn.Module):
    def __init__(self, num_classes=38):
        super(UNetClassification, self).__init__()
        self.encoder = models.resnet18(pretrained=True)
        self.encoder.fc = nn.Identity()  # Remove FC layer, keep feature maps

        # U-Net Decoder (simple version)
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(512, 256, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1)),  # Reduce to (batch_size, 128, 1, 1)
            nn.Flatten(),  # Convert to (batch_size, 128)
            nn.Linear(128, num_classes)  # Final classification layer
        )

    def forward(self, x):
        x = self.encoder(x)  # Extract features -> shape: (batch_size, 512)
        x = x.view(x.shape[0], 512, 1, 1)  # Reshape to (batch_size, 512, 1, 1)
        x = self.decoder(x)  # Decode and classify
        return x


# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Initialize the UNet model for classification
model = UNetClassification(num_classes=38)
model = model.to(device)

# Define loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Enable Mixed Precision Training
scaler = GradScaler()

# DataLoader optimizations (Assuming train_dataset, val_dataset, and test_dataset are already defined)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# Training setup
num_epochs = 10
train_acc_history = []
val_acc_history = []
test_acc_history = []

for epoch in range(num_epochs):
    model.train()
    correct = 0
    total = 0
    running_loss = 0.0

    loop = tqdm(train_loader, leave=True, desc=f"Epoch {epoch+1}/{num_epochs}")
    for images, labels in loop:
        images = images.to(device)  # No need to index, just move tensor to device
        labels = labels.to(device)  # Move labels to device
        
        optimizer.zero_grad()

        with torch.amp.autocast(device_type="cuda"):
            outputs = model(images)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

        loop.set_postfix(loss=f"{running_loss / len(train_loader):.4f}", acc=f"{100 * correct / total:.2f}%")

# Save the trained model
torch.save(model.state_dict(), "unet_trained.pth")
print("\n🚀 Model saved as unet_trained.pth")
# Out:
# Using device: cuda
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 192MB/s]
# Epoch 1/10: 100%|██████████| 1019/1019 [01:02<00:00, 16.28it/s, acc=70.36%, loss=1.0794]
# Epoch 2/10: 100%|██████████| 1019/1019 [01:00<00:00, 16.93it/s, acc=96.93%, loss=0.1119]
# Epoch 3/10: 100%|██████████| 1019/1019 [01:00<00:00, 16.93it/s, acc=98.29%, loss=0.0586]
# Epoch 4/10: 100%|██████████| 1019/1019 [01:00<00:00, 16.96it/s, acc=98.81%, loss=0.0412]
# Epoch 5/10: 100%|██████████| 1019/1019 [01:00<00:00, 16.98it/s, acc=98.85%, loss=0.0376]
# Epoch 6/10: 100%|██████████| 1019/1019 [01:00<00:00, 16.86it/s, acc=99.07%, loss=0.0313]
# Epoch 7/10: 100%|██████████| 1019/1019 [01:01<00:00, 16.56it/s, acc=99.21%, loss=0.0280]
# Epoch 8/10: 100%|██████████| 1019/1019 [01:00<00:00, 16.86it/s, acc=99.35%, loss=0.0255]
# Epoch 9/10: 100%|██████████| 1019/1019 [01:00<00:00, 16.80it/s, acc=99.39%, loss=0.0217]
# Epoch 10/10: 100%|██████████| 1019/1019 [01:00<00:00, 16.90it/s, acc=99.51%, loss=0.0164]
# 🚀 Model saved as unet_trained.pth

# %%
import numpy as np
import torch

class_names = dataset.classes  # Ensure dataset has class name
num_classes = len(class_names) 

# Function to calculate per-class accuracy for different datasets
def calculate_per_class_accuracy(model, data_loaders, device, datasets=["Training", "Validation", "Test"]):
    for dataset_type, data_loader in zip(datasets, data_loaders):
        model.eval()
        class_correct = np.zeros(num_classes)
        class_total = np.zeros(num_classes)

        with torch.no_grad():
            for images, labels in data_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs, 1)

                for i in range(len(labels)):
                    label = labels[i].item()
                    class_correct[label] += (predicted[i] == label).item()
                    class_total[label] += 1

        # Print per-class accuracy for the current dataset
        print(f"\n📊 Final Per-Class {dataset_type} Accuracy:\n")
        for i in range(num_classes):
            accuracy = 100 * class_correct[i] / class_total[i] if class_total[i] > 0 else 0
            print(f"{class_names[i]}: {dataset_type} = {accuracy:.2f}%")


# ---------- Calculate Per-Class Accuracy for Training, Validation, and Test Data ----------
# List of data loaders for training, validation, and test datasets
data_loaders = [train_loader, val_loader, test_loader]

# List of dataset names
datasets = ["Training", "Validation", "Test"]

# Call the function for calculating accuracy
calculate_per_class_accuracy(model, data_loaders, device, datasets=datasets)
# Out:
# 📊 Final Per-Class Training Accuracy:
#
# Apple___Apple_scab: Training = 99.22%
# Apple___Black_rot: Training = 99.74%
# Apple___Cedar_apple_rust: Training = 100.00%
# Apple___healthy: Training = 99.80%
# Blueberry___healthy: Training = 100.00%
# Cherry_(including_sour)___Powdery_mildew: Training = 99.69%
# Cherry_(including_sour)___healthy: Training = 100.00%
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: Training = 100.00%
# Corn_(maize)___Common_rust_: Training = 100.00%
# Corn_(maize)___Northern_Leaf_Blight: Training = 99.31%
# Corn_(maize)___healthy: Training = 100.00%
# Grape___Black_rot: Training = 100.00%
# Grape___Esca_(Black_Measles): Training = 100.00%
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): Training = 100.00%
# Grape___healthy: Training = 100.00%
# Orange___Haunglongbing_(Citrus_greening): Training = 100.00%
# Peach___Bacterial_spot: Training = 100.00%
# Peach___healthy: Training = 100.00%
# Pepper,_bell___Bacterial_spot: Training = 99.33%
# Pepper,_bell___healthy: Training = 100.00%
# Potato___Early_blight: Training = 100.00%
# Potato___Late_blight: Training = 99.50%
# Potato___healthy: Training = 100.00%
# Raspberry___healthy: Training = 100.00%
# Soybean___healthy: Training = 100.00%
# Squash___Powdery_mildew: Training = 100.00%
# Strawberry___Leaf_scorch: Training = 100.00%
# Strawberry___healthy: Training = 100.00%
# Tomato___Bacterial_spot: Training = 100.00%
# Tomato___Early_blight: Training = 99.33%
# Tomato___Late_blight: Training = 100.00%
# Tomato___Leaf_Mold: Training = 99.83%
# Tomato___Septoria_leaf_spot: Training = 99.90%
# Tomato___Spider_mites Two-spotted_spider_mite: Training = 99.90%
# Tomato___Target_Spot: Training = 99.65%
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: Training = 100.00%
# Tomato___Tomato_mosaic_virus: Training = 100.00%
# Tomato___healthy: Training = 100.00%
#
# 📊 Final Per-Class Validation Accuracy:
#
# Apple___Apple_scab: Validation = 95.90%
# Apple___Black_rot: Validation = 100.00%
# Apple___Cedar_apple_rust: Validation = 100.00%
# Apple___healthy: Validation = 99.39%
# Blueberry___healthy: Validation = 100.00%
# Cherry_(including_sour)___Powdery_mildew: Validation = 100.00%
# Cherry_(including_sour)___healthy: Validation = 100.00%
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: Validation = 95.58%
# Corn_(maize)___Common_rust_: Validation = 100.00%
# Corn_(maize)___Northern_Leaf_Blight: Validation = 93.97%
# Corn_(maize)___healthy: Validation = 100.00%
# Grape___Black_rot: Validation = 97.94%
# Grape___Esca_(Black_Measles): Validation = 100.00%
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): Validation = 100.00%
# Grape___healthy: Validation = 100.00%
# Orange___Haunglongbing_(Citrus_greening): Validation = 100.00%
# Peach___Bacterial_spot: Validation = 99.59%
# Peach___healthy: Validation = 100.00%
# Pepper,_bell___Bacterial_spot: Validation = 95.12%
# Pepper,_bell___healthy: Validation = 100.00%
# Potato___Early_blight: Validation = 99.47%
# Potato___Late_blight: Validation = 95.92%
# Potato___healthy: Validation = 94.44%
# Raspberry___healthy: Validation = 100.00%
# Soybean___healthy: Validation = 100.00%
# Squash___Powdery_mildew: Validation = 100.00%
# Strawberry___Leaf_scorch: Validation = 99.55%
# Strawberry___healthy: Validation = 100.00%
# Tomato___Bacterial_spot: Validation = 99.32%
# Tomato___Early_blight: Validation = 94.61%
# Tomato___Late_blight: Validation = 99.21%
# Tomato___Leaf_Mold: Validation = 97.86%
# Tomato___Septoria_leaf_spot: Validation = 98.07%
# Tomato___Spider_mites Two-spotted_spider_mite: Validation = 97.15%
# Tomato___Target_Spot: Validation = 99.63%
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: Validation = 99.54%
# Tomato___Tomato_mosaic_virus: Validation = 100.00%
# Tomato___healthy: Validation = 100.00%
#
# 📊 Final Per-Class Test Accuracy:
#
# Apple___Apple_scab: Test = 97.60%
# Apple___Black_rot: Test = 98.17%
# Apple___Cedar_apple_rust: Test = 100.00%
# Apple___healthy: Test = 99.40%
# Blueberry___healthy: Test = 99.67%
# Cherry_(including_sour)___Powdery_mildew: Test = 98.54%
# Cherry_(including_sour)___healthy: Test = 99.39%
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: Test = 94.06%
# Corn_(maize)___Common_rust_: Test = 99.57%
# Corn_(maize)___Northern_Leaf_Blight: Test = 94.69%
# Corn_(maize)___healthy: Test = 100.00%
# Grape___Black_rot: Test = 99.57%
# Grape___Esca_(Black_Measles): Test = 100.00%
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): Test = 99.49%
# Grape___healthy: Test = 98.94%
# Orange___Haunglongbing_(Citrus_greening): Test = 99.91%
# Peach___Bacterial_spot: Test = 99.33%
# Peach___healthy: Test = 100.00%
# Pepper,_bell___Bacterial_spot: Test = 97.44%
# Pepper,_bell___healthy: Test = 99.66%
# Potato___Early_blight: Test = 99.47%
# Potato___Late_blight: Test = 93.63%
# Potato___healthy: Test = 100.00%
# Raspberry___healthy: Test = 97.01%
# Soybean___healthy: Test = 100.00%
# Squash___Powdery_mildew: Test = 100.00%
# Strawberry___Leaf_scorch: Test = 99.49%
# Strawberry___healthy: Test = 100.00%
# Tomato___Bacterial_spot: Test = 99.54%
# Tomato___Early_blight: Test = 90.91%
# Tomato___Late_blight: Test = 99.48%
# Tomato___Leaf_Mold: Test = 98.93%
# Tomato___Septoria_leaf_spot: Test = 96.71%
# Tomato___Spider_mites Two-spotted_spider_mite: Test = 96.83%
# Tomato___Target_Spot: Test = 97.79%
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: Test = 99.63%
# Tomato___Tomato_mosaic_virus: Test = 100.00%
# Tomato___healthy: Test = 99.69%

# %%
import numpy as np
import torch
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Initialize lists for storing true labels and predicted probabilities
y_true = []
y_scores = []

# Switch to evaluation mode
model.eval()

# Test Accuracy and collect predictions
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

test_acc = 100 * correct / total
print(f"✅ Test Accuracy: {test_acc:.2f}%")

# Collect true labels and predicted probabilities for PR Curve
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        probs = torch.nn.functional.softmax(outputs, dim=1)
        
        y_true.extend(labels.cpu().numpy())
        y_scores.extend(probs.cpu().numpy())

# Convert lists to numpy arrays for PR curve calculation
y_true = np.array(y_true)
y_scores = np.array(y_scores)

# Plot Precision-Recall curves for each class
plt.figure(figsize=(10, 10))
for i in range(len(class_names)):
    precision, recall, _ = precision_recall_curve(y_true == i, y_scores[:, i])
    avg_precision = average_precision_score(y_true == i, y_scores[:, i])
    plt.plot(recall, precision, label=f"{class_names[i]} (AP={avg_precision:.2f})")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve for Plant Disease Classification")
plt.legend()
plt.show()
# Out:
# ✅ Test Accuracy: 98.90%
